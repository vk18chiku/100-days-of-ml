# %%
import pickle
import numpy as np
import builtins

# %%
pipe = pickle.load(builtins.open('pipe.pkl','rb'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pipe = pickle.load(builtins.open('pipe.pkl','rb'))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pipe.pkl'
