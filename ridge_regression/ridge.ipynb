# %%
import pandas as pd
import numpy as np
from sklearn.datasets import make_regression
from sklearn.metrics import r2_score

# %%
X,y=make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20,random_state=13)

# %%
X
# Out:
# array([[-0.71239066],
#        [-0.43714566],
#        [-0.45375238],
#        [ 0.95283061],
#        [ 0.23785784],
#        [ 0.86121137],
#        [-0.24332625],
#        [ 0.18494595],
#        [-0.72099967],
#        [-0.42989708],
#        [ 2.01522083],
#        [ 0.39724133],
#        [ 0.20780005],
#        [-0.23242587],
#        [-0.76862702],
#        [ 0.45315861],
#        [ 0.63988397],
#        [ 0.3595323 ],
#        [-1.61510796],
#        [ 1.74924179],
#        [-0.78898902],
#        [-0.51196509],
#        [-0.92833523],
#        [ 2.15038297],
#        [-0.2073497 ],
#        [-1.63909341],
#        [-0.33861825],
#        [-0.32212366],
#        [-0.48137142],
#        [-0.52316421],
#        [ 0.72196506],
#        [ 0.76591105],
#        [ 0.45348104],
#        [-1.26160595],
#        [-2.18711527],
#        [-1.18541881],
#        [ 0.21745166],
#        [ 1.33031692],
#        [-1.08718159],
#        [ 0.56226171],
#        [-1.51284512],
# ...

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [27.82809103]
# -2.29474455867698

# %%
y_pred=lr.predict(X)
print(r2_score(y,y_pred))
# Out:
# 0.7035182396294911

# %%
from sklearn.linear_model import Ridge
rr=Ridge(alpha=10)
rr.fit(X,y)
print(rr.coef_)
print(rr.intercept_)
# Out:
# [24.9546267]
# -2.1269130035235726

# %%
y_pred=rr.predict(X)
print(r2_score(y_pred,y))
# Out:
# 0.4626734592157088

# %%
rr1 = Ridge(alpha=100)
rr1.fit(X,y)
print(rr1.coef_)
print(rr1.intercept_)
# Out:
# [12.93442104]
# -1.4248441496033308

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)
plt.plot(X,lr.predict(X),color='red',label='alpha0')
plt.plot(X,rr.predict(X),color='green',label='alpha10')
plt.plot(X,rr1.predict(X),color='yellow',label='alpha100')
plt.legend()

# %%
def linear_regression(X,y,alpha=1):
    x_mean = X.mean()
    y_mean = y.mean()
    
    num = 0
    den = 0
    
    for i in range(X.shape[0]):
        num = num + (y[i] - y_mean) * (X[i] - x_mean)
        den = den + (X[i] - x_mean) * (X[i] - x_mean)
        
    m = num/(den + alpha)
    b = y_mean - m*x_mean
        
    return m,b

# %%
class MeraRidge:
    def __init__(self,alpha=0.1):
        self.m=None
        self.b=None
        self.alpha=alpha

    def fit(self,X_train,y_train):
        num=0
        den=0
        for i in range(X_train.shape[0]):
            num=num+(y_train[i]-y_train.mean()) * (X_train[i]-X_train[i]-X_train.mean())
            den=den+(X_train[i]-X_train.mean())*(X_train[i]-X_train.mean())

        self.m=num/(den+self.alpha)
        self.b=y_train.mean() - (self.m * X_train.mean())

        print(self.m,self.b)

    def predict(X_test):
        pass

# %%
reg = MeraRidge(alpha=100)

# %%
reg.fit(X,y)
# Out:
# [-2.30250323e-17] [-0.66937836]
